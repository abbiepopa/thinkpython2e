# %%
import os

# %%
for root, dirs, files in os.walk('/Users/abbiepopa/Documents/datascience_projects/'):
    for name in files:
        print(name)
# Out:
# .DS_Store
# Dockerfile
# hello.sh
# .Rapp.history
# concat.R
# fastFib.R
# fib.c
# rw1.R
# rw2dPlot.R
# slowFib.R
# config
# description
# FETCH_HEAD
# HEAD
# index
# ORIG_HEAD
# packed-refs
# applypatch-msg.sample
# commit-msg.sample
# post-update.sample
# pre-applypatch.sample
# pre-commit.sample
# pre-push.sample
# pre-rebase.sample
# pre-receive.sample
# prepare-commit-msg.sample
# update.sample
# exclude
# HEAD
# master
# HEAD
# 487ac9910b27783638be453a7806271f811d70
# 6360ef4fdcf43dab64a57e7ef5f201e476f598
# 126fec2facefbff155365036d26834dd1992a2
# 053a4de778f17f10a8d41eb4eff96b54507ef2
# bbfb257f06f3ecc5461ff1157a9326d64e2525
# d6a709a061af6fcdfd6ed8eb77ba7aab24990a
# b364ba5cfe0f50711024d7b80b3c0d8dd1a54b
# f20e922ff373d475e854e64798a91c2e5930ec
# efc31d38e210ea8d5eb22a2183d7cc1a3b8e71
# 300aa620515f60a2928a379a96e791cb72fca0
# 54fe76367bbd077b43dea15287aa3bf0097dea
# a60f20a5ef634a8f8e82d81577c278d0dd2ade
# a6b44ec4df123ea93487ca5d5aa0ceacb3d67a
# ...
